# %%
import pandas as pd
import numpy as np
c_vul = pd.read_csv('code_dataset/C_vul_detection.csv')
cwe_top25 = ['CWE-79','CWE-787', 'CWE-89','CWE-352','CWE-22']

# %%
c_vul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14474 entries, 0 to 14473
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  14474 non-null  object
#  1   signature             14474 non-null  object
#  2   nloc                  14474 non-null  int64
#  3   parameters            14474 non-null  object
#  4   token_count           14474 non-null  int64
#  5   code                  14474 non-null  object
#  6   start_line            14474 non-null  int64
#  7   end_line              14474 non-null  int64
#  8   before_change         14474 non-null  bool
#  9   cwe_id                14474 non-null  object
#  10  programming_language  14474 non-null  object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 1.1+ MB

# %%
# Out:
#                               name  \
# 0                    _dl_dst_count
# 1                    _dl_dst_count
# 2               _dl_dst_substitute
# 3               _dl_dst_substitute
# 4      expand_dynamic_string_token
# ...                            ...
# 14469              passwd_to_utf16
# 14470              passwd_to_utf16
# 14471                read_password
# 14472                read_password
# 14473                          w2p
#
#                                                signature  nloc  \
# 0        _dl_dst_count( const char * name , int is_path)    22
# 1        _dl_dst_count( const char * name , int is_path)    29
# 2      _dl_dst_substitute( struct link_map * l , cons...    51
# 3      _dl_dst_substitute( struct link_map * l , cons...    57
# 4      expand_dynamic_string_token( struct link_map *...    14
# ...                                                  ...   ...
# 14469  passwd_to_utf16( unsigned char * in_passwd , i...    67
# ...
